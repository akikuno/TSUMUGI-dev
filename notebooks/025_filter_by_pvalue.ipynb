# %% [markdown]
# # Filter dataset by P value < 0.0001 (10^-4)

# %% [markdown]
# ## Move the top directory

# %%
import os
os.getcwd()
os.chdir('../')
os.getcwd()
# Out:
# '/mnt/e/impc-genes_with_similar_phenotypes'

# %%
from pathlib import Path
from collections import defaultdict
from itertools import combinations
import csv
import pandas as pd

# %%
path_data = Path("data", "impc", "statistical-results-ALL.csv")

# %%
data = pd.read_csv(path_data)
# Out:
# /tmp/ipykernel_1448010/3194353688.py:1: DtypeWarning: Columns (25,60) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(path_data)
#         phenotyping_center  intercept_estimate  procedure_id  \
# 0                      TCP            0.036441           NaN
# 1                     WTSI            0.198528           NaN
# 2                     WTSI                 NaN           NaN
# 3                 UC Davis           -8.559718           NaN
# 4                      JAX                 NaN           NaN
# ...                    ...                 ...           ...
# 2062767            CCP-IMG                 NaN           NaN
# 2062768        MRC Harwell           16.068134           NaN
# 2062769               WTSI                 NaN           NaN
# 2062770            CCP-IMG                 NaN           NaN
# 2062771               WTSI                 NaN           NaN
#
#          mutant_biological_model_id  rotated_residuals_test  \
# 0                               NaN                     NaN
# 1                               NaN                     NaN
# 2                               NaN                     NaN
# 3                               NaN                     NaN
# 4                               NaN                     NaN
# ...                             ...                     ...
# 2062767                         NaN                     NaN
# 2062768                         NaN                     NaN
# 2062769                         NaN                     NaN
# 2062770                         NaN                     NaN
# 2062771                         NaN                     NaN
#
#          weight_effect_p_value  male_mutant_count  pipeline_stable_key  \
# 0                 1.722811e-11                NaN                    9
# 1                 1.654211e-16                7.0                    1
# 2                          NaN                7.0                    4
# 3                 0.000000e+00                8.0                   13
# 4                          NaN                8.0                   12
# ...                        ...                ...                  ...
# 2062767                    NaN                NaN                   44
# 2062768           1.488420e-02                7.0                    8
# 2062769                    NaN                3.0                   15
# 2062770                    NaN                NaN                   44
# 2062771                    NaN                7.0                   15
#
#          female_ko_effect_p_value pipeline_stable_id  ...  pipeline_id  \
# 0                             NaN            TCP_001  ...          NaN
# 1                        0.405457          ESLIM_001  ...          NaN
# 2                        0.235520          M-G-P_001  ...          NaN
# 3                        0.862062            UCD_001  ...          NaN
# 4                        1.000000            JAX_001  ...          NaN
# ...                           ...                ...  ...          ...
# 2062767                       NaN            CCP_001  ...          NaN
# 2062768                  0.165806           HRWL_001  ...          NaN
# 2062769                       NaN            MGP_001  ...          NaN
# 2062770                       NaN            CCP_001  ...          NaN
# 2062771                       NaN            MGP_001  ...          NaN
#
#         group_1_genotype male_ko_parameter_estimate  \
# 0                control                        NaN
# 1                control                  -0.888437
# 2                    NaN                        NaN
# 3                control                  -0.885874
# 4                    NaN                   0.000000
# ...                  ...                        ...
# 2062767              NaN                        NaN
# 2062768          control                   0.177134
# 2062769              NaN                        NaN
# 2062770              NaN                        NaN
# 2062771              NaN                        NaN
#
#         genotype_effect_parameter_estimate categories  parameter_id  \
# 0                                 0.005079        NaN           NaN
# 1                                -0.151456        NaN           NaN
# 2                                      NaN        NaN           NaN
# 3                                -0.078817        NaN           NaN
# 4                                      NaN        NaN           NaN
# ...                                    ...        ...           ...
# 2062767                                NaN        NaN           NaN
# 2062768                          -0.244314        NaN           NaN
# 2062769                           0.000000        NaN           NaN
# 2062770                                NaN        NaN           NaN
# 2062771                           0.000000        NaN           NaN
#
#         batch_significant genotype_effect_stderr_estimate  resource_fullname  \
# 0                    True                        0.016069               IMPC
# 1                   False                        0.181751        EuroPhenome
# 2                     NaN                             NaN        EuroPhenome
# 3                    True                        0.453165               IMPC
# 4                     NaN                             NaN               IMPC
# ...                   ...                             ...                ...
# 2062767               NaN                             NaN               IMPC
# 2062768              True                        0.175660               IMPC
# 2062769               NaN                             NaN                 3i
# 2062770               NaN                             NaN               IMPC
# 2062771               NaN                             NaN                 3i
#
#          significant
# 0              False
# 1               True
# 2              False
# 3              False
# 4              False
# ...              ...
# 2062767        False
# 2062768        False
# 2062769        False
# 2062770        False
# 2062771        False
#
# [2062772 rows x 88 columns]

# %%
print(len(data)) # 2062772
# Out:
# 2062772

# %%
# Filter by p_value < 0.0001
threshold = 0.0001
data = data[data["p_value"] < threshold]

# Filter by mp_term_name is not NaN
data = data.dropna(subset=["mp_term_name"])

# Filter by effect_size is not NaN

data = data.dropna(subset=["effect_size"])

# %%
data # 39356 rows
# Out:
#         phenotyping_center  intercept_estimate  procedure_id  \
# 78                     TCP                 NaN           NaN
# 107                    BCM                 NaN           NaN
# 173                   WTSI           82.874590           NaN
# 189                   WTSI            2.067209           NaN
# 214            MRC Harwell            0.094135           NaN
# ...                    ...                 ...           ...
# 2062427                ICS            1.886719           NaN
# 2062460                JAX                 NaN           NaN
# 2062492           UC Davis           62.599150           NaN
# 2062707                JAX                 NaN           NaN
# 2062726           UC Davis            0.172341           NaN
#
#          mutant_biological_model_id  rotated_residuals_test  \
# 78                              NaN                     NaN
# 107                             NaN                     NaN
# 173                             NaN                     NaN
# 189                             NaN                     NaN
# 214                             NaN                     NaN
# ...                             ...                     ...
# 2062427                         NaN                     NaN
# 2062460                         NaN                     NaN
# 2062492                         NaN                     NaN
# 2062707                         NaN                     NaN
# 2062726                         NaN                     NaN
#
#          weight_effect_p_value  male_mutant_count  pipeline_stable_key  \
# 78                         NaN                NaN                    9
# 107                        NaN                NaN                   16
# 173                        NaN                7.0                   15
# 189                   0.000000                NaN                    4
# 214                   0.005916               12.0                   49
# ...                        ...                ...                  ...
# 2062427                    NaN                7.0                   10
# 2062460                    NaN                7.0                   12
# 2062492               0.066821                8.0                   13
# 2062707                    NaN                7.0                   12
# 2062726               0.000300                5.0                   13
#
#          female_ko_effect_p_value pipeline_stable_id  ...  pipeline_id  \
# 78                            NaN            TCP_001  ...          NaN
# 107                           NaN            BCM_001  ...          NaN
# 173                  1.144336e-06            MGP_001  ...          NaN
# 189                           NaN          M-G-P_001  ...          NaN
# 214                  2.945420e-82         HRWLLA_001  ...          NaN
# ...                           ...                ...  ...          ...
# 2062427              1.191867e-08            ICS_001  ...          NaN
# 2062460              2.502193e-04            JAX_001  ...          NaN
# 2062492              8.359806e-04            UCD_001  ...          NaN
# 2062707              7.356204e-15            JAX_001  ...          NaN
# 2062726              1.694129e-07            UCD_001  ...          NaN
#
#         group_1_genotype male_ko_parameter_estimate  \
# 78                   NaN                        NaN
# 107                  NaN                        NaN
# 173              control                 -10.137384
# 189              control                        NaN
# 214              control                  -0.009936
# ...                  ...                        ...
# 2062427          control                   3.997457
# 2062460              NaN                 100.548162
# 2062492          control                 -25.258854
# 2062707              NaN                 222.933897
# 2062726          control                   0.082636
#
#         genotype_effect_parameter_estimate categories  parameter_id  \
# 78                                     NaN        NaN           NaN
# 107                                    NaN        NaN           NaN
# 173                              23.474848        NaN           NaN
# 189                               0.097840        NaN           NaN
# 214                              26.981602        NaN           NaN
# ...                                    ...        ...           ...
# 2062427                           4.084710        NaN           NaN
# 2062460                                NaN        NaN           NaN
# 2062492                         -20.409706        NaN           NaN
# 2062707                                NaN        NaN           NaN
# 2062726                           0.092878        NaN           NaN
#
#         batch_significant genotype_effect_stderr_estimate  resource_fullname  \
# 78                    NaN                             NaN               IMPC
# 107                   NaN                             NaN               IMPC
# 173                  True                        4.800326               IMPC
# 189                  True                        0.019675                MGP
# 214                  True                        1.015066               IMPC
# ...                   ...                             ...                ...
# 2062427             False                        0.448757               IMPC
# 2062460               NaN                             NaN               IMPC
# 2062492              True                        3.874395               IMPC
# 2062707               NaN                             NaN               IMPC
# 2062726              True                        0.015375               IMPC
#
#          significant
# 78              True
# 107             True
# 173             True
# 189             True
# 214             True
# ...              ...
# 2062427         True
# 2062460         True
# 2062492         True
# 2062707         True
# 2062726         True
#
# [39356 rows x 88 columns]

# %%
# NaNがあるか確認

data[data["marker_symbol"] == "Lepr"]["effect_size"].isnull().sum() # 0
# Out:
# np.int64(0)

# %%
data.to_csv("data/statistical_filtered.csv", index=False)
# data.to_csv("data/statistical_filtered.csv.gz", index=False, compression="gzip")
